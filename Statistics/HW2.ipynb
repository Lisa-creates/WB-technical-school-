# %% [markdown]
# **Задача 1**
#
# $$ H_0: \mu = 12 $$
# $$ H_A: μ \neq 12 $$
# $$\overline{X} = 12.7 $$
# $$ S^2 = 0.63, тогда$$
# $$ T = \frac{(12.7 - 12) * \sqrt{6}}{\sqrt{0.63}} \approx 2.16 => p \approx 0.07 > 0.05 =>  \text{результаты статистически незначимы}$$
#
# **Ответ (длинно):** нет оснований отвергнуть нулевую гипотезу при уровне значимости равном 0.05
#
# **Ответ (которотко):** Да

# %% [markdown]
# **Задача 2.**
# Перейдём к новой выборке Z, которая равна разности первой и второй выборки:
# [0.4, -0.4, -0.6, -0.8, -0.3, 1.5, 0.1, 0.1, 0.3, -0.3]
#
# $$ H_0: \mu_z = 0 $$
# $$ H_A: μ_z \neq 0 $$
# $$\overline{X} = 0 =>  $$
# $$ T = \frac{(0 - 0) * \sqrt{9}}{\sqrt{S^2}} = 0 => p = 1 > 0.05 =>  \text{результаты статистически незначимы}$$
#
# **Ответ (длинно):** нет оснований отвергнуть нулевую гипотезу при уровне значимости равном 0.05
#
# **Ответ (которотко):** Нет, полученные результаты не позволояют сделать такой вывод

# %% [markdown]
# **Задача 3.**
# Введём обозначения: c - городские, v - деревенские
#
# $$ H_0: \mu_c = \mu_v $$
# $$ H_A: \mu_c \neq \mu_v $$
# $$\overline{X_c} = 143.8,  \overline{X_v} = 143.3$$
# $$ S_с^2 = 615.16, S_v^2 = 892.22, тогда$$
# $$ T = \frac{(143.8 - 143.3)}{\sqrt{\frac{615.16}{10} + \frac{892.22}{9}}} \approx 0.035 => p \approx 0.97 > 0.05 =>  \text{результаты статистически незначимы}$$
#
# **Ответ (длинно):** нет оснований отвергнуть нулевую гипотезу при уровне значимости равном 0.05. Соответственно нельзя сказать, что жители городов имеют более высокое артериальное давление
#
# **Ответ (которотко):** Нет

# %% [markdown]
# **Задача 4.**
#
# n = 5000
# m = 2500
# $$p_0 = 0.52$$
#
# $$ H_0: p = p_0 $$
# $$ H_A: p \neq p_0 $$
# $$\overline{X} = 0 =>  $$
# $$ T = \frac{2500 - 5000 * 0.52}{5000 * 0.52 * 0.48} \approx - 2.83 => p \approx 0.0023 < 0.05 =>  \text{результаты статистически значимы}$$
#
# **Ответ (длинно):** отклоняем нулевую гипотезув пользу альтернативной на уровне значимости 0.05
#
# **Ответ (которотко):** Нет

# %% [markdown]
# **Задача 5**
#
# Ответ:
# 1. Во втором исследование среднее X2 гораздо больше, чем в первом иследовании, что может свидетельствовать о выбросах
# 2. Выборка уменьшилась вот втором эксперименте
